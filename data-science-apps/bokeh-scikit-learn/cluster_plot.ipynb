# %% [markdown]
# # Simple Clustering Visualization with Scikit-learn and Bokeh

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.palettes import Spectral6
from bokeh.models import ColumnDataSource

# %%
np.random.seed(0)

# %%
output_notebook()
# Out:
#
# <script type="text/javascript" src="http://cdn.pydata.org/bokeh/dev/bokeh-0.11.0dev3.min.js"></script>
# <script type="text/javascript" src="http://cdn.pydata.org/bokeh/dev/bokeh-widgets-0.11.0dev3.min.js"></script>
# <script type="text/javascript">
#     Bokeh.set_log_level("info");
# </script>
#
# <link rel="stylesheet" href="http://cdn.pydata.org/bokeh/dev/bokeh-0.11.0dev3.min.css" type="text/css" />
# <link rel="stylesheet" href="http://cdn.pydata.org/bokeh/dev/bokeh-widgets-0.11.0dev3.min.css" type="text/css" />
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>

# %%
# Generate datasets. We choose the size big enough to see the scalability
# of the algorithms, but not too big to avoid too long running times
n_samples = 1500
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=.5, noise=.05)

colors = np.array([Spectral6])

clustering_algorithm = 'MiniBatchKMeans'

# %%
source = ColumnDataSource(data=dict())

plot = figure(plot_width=400, plot_height=400, title=clustering_algorithm,
              title_text_font_size='10pt')

# %%
X, y = noisy_circles
# normalize dataset for easier parameter selection
X = StandardScaler().fit_transform(X)
two_means = cluster.MiniBatchKMeans(n_clusters=2)
two_means.fit(X)
y_pred = two_means.predict(X)
colors = [Spectral6[i] for i in y_pred]

plot.circle(X[:, 0], X[:, 1], fill_color=colors, line_color=None)

# %%
show(plot)
# Out:
#     <script type="text/javascript">
#         Bokeh.$(function() {
#
#           var websocket_url = null;
#
#         var docs_json = {"f5f0588b-3ebd-4c11-8eb6-7db9a48bbd63": {"title": "Bokeh Application", "roots": {"root_ids": ["58059195-3e1d-471d-8569-95e6f858fe65"], "references": [{"attributes": {"tags": [], "name": null, "dimensions": ["width", "height"], "plot": {"subtype": "Figure", "id": "58059195-3e1d-471d-8569-95e6f858fe65", "type": "Plot"}}, "id": "10634d48-0842-458f-a7ca-db55857e59ab", "type": "WheelZoomTool"}, {"attributes": {"tags": [], "name": null, "dimensions": ["width", "height"], "plot": {"subtype": "Figure", "id": "58059195-3e1d-471d-8569-95e6f858fe65", "type": "Plot"}}, "id": "fb7eba08-7baa-49f4-86b6-961de843d021", "type": "PanTool"}, {"attributes": {"line_dash_offset": 0, "angle": {"units": "rad", "value": 0.0}, "tags": [], "radius": null, "line_join": "miter", "name": null, "line_width": {"value": 1}, "radius_dimension": "x", "y": {"field": "y"}, "fill_color": {"field": "fill_color"}, "visible": true, "x": {"field": "x"}, "size": {"units": "screen", "value": 4}, "line_cap": "butt", "line_alpha": {"value": 1.0}, "line_color": {"value": null}, "line_dash": [], "fill_alpha": {"value": 1.0}}, "id": "ff6600a3-200e-49e3-8dec-c95b12cc035b", "type": "Circle"}, {"attributes": {"line_dash_offset": 0, "angle": {"units": "rad", "value": 0.0}, "tags": [], "radius": null, "line_join": "miter", "name": null, "line_width": {"value": 1}, "radius_dimension": "x", "y": {"field": "y"}, "fill_color": {"value": "#1f77b4"}, "visible": true, "x": {"field": "x"}, "size": {"units": "screen", "value": 4}, "line_cap": "butt", "line_alpha": {"value": 0.1}, "line_color": {"value": "#1f77b4"}, "line_dash": [], "fill_alpha": {"value": 0.1}}, "id": "ad427e47-949b-4874-ad0b-7378a87253f7", "type": "Circle"}, {"attributes": {"grid_line_alpha": {"value": 1.0}, "minor_grid_line_join": "miter", "tags": [], "grid_line_width": {"value": 1}, "minor_grid_line_width": {"value": 1}, "ticker": {"id": "f7a377bc-6485-419e-828e-b826c0c4d0bf", "type": "BasicTicker"}, "minor_grid_line_dash_offset": 0, "grid_line_join": "miter", "grid_line_dash_offset": 0, "plot": {"subtype": "Figure", "id": "58059195-3e1d-471d-8569-95e6f858fe65", "type": "Plot"}, "level": "underlay", "minor_grid_line_alpha": {"value": 1.0}, "band_fill_alpha": {"value": 0}, "minor_grid_line_dash": [], "minor_grid_line_cap": "butt", "y_range_name": "default", "grid_line_dash": [], "dimension": 0, "minor_grid_line_color": {"value": null}, "band_fill_color": {"value": null}, "bounds": "auto", "grid_line_cap": "butt", "grid_line_color": {"value": "#cccccc"}, "name": null, "x_range_name": "default"}, "id": "9e7a4e43-8bea-4fa6-a8d5-5cf29867d27c", "type": "Grid"}, {"attributes": {"tags": [], "min_interval": 0.0, "max_interval": null, "desired_num_ticks": 6, "num_minor_ticks": 5, "base": 10.0, "mantissas": [1, 2, 5], "name": null}, "id": "4b36550a-d223-4313-aba0-7856c923b071", "type": "BasicTicker"}, {"attributes": {"tags": [], "name": null, "dimensions": ["width", "height"], "plot": {"subtype": "Figure", "id": "58059195-3e1d-471d-8569-95e6f858fe65", "type": "Plot"}}, "id": "5aa519e4-845f-4a86-a4ae-afa9a40ecbce", "type": "BoxZoomTool"}, {"attributes": {"tags": [], "name": null, "plot": {"subtype": "Figure", "id": "58059195-3e1d-471d-8569-95e6f858fe65", "type": "Plot"}}, "id": "aa51a74e-5cc4-4e3b-87d0-75ac38ed7c6d", "type": "ResizeTool"}, {"attributes": {"column_names": ["x", "y", "fill_color"], "selected": {"1d": {"indices": []}, "0d": {"flag": false, "indices": []}, "2d": {"indices": []}}, "callback": null, "tags": [], "name": null, "data": {"x": [-1.211678778277259, 1.663584897191907, 0.9790931668572626, 1.5588948611943594, 0.7774611037215345, -0.9584490005763536, 1.6709033488978684, 0.2840149682492494, -1.0929619489896154, 0.7553318828461397, 0.3088960297782865, -0.39189887039311694, 0.17126800374861795, -0.18709525434065777, 1.7283446025167228, 1.347025173205762, -0.07902924243556153, 0.7684178048102507, -1.8366117288004933, -0.4087321114968605, 0.12776446615548487, 1.1711637732707436, 1.3546145642568 ...
